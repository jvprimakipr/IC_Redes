# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
jupyterhub = '/dados/home/joaoviniciuspr'
jupyterlab = '/Users/jjoao/OneDrive/Documentos/Faculdade'
ju = jupyterhub
directory = ju+'/IC_Redes/Trabalhos/UCM/Fase1/Homem_de_Ferro_1'

# %%
degree=pd.read_csv(directory+'/Degree.csv')
degree=degree.set_index("ID")
degree.fillna('',inplace=True)
count = degree.groupby("Degree").size()

# %%
fig, ax = plt.subplots(1,2,figsize=(16,8))
ax[0].plot(count.index,count.values,"o")
ax[0].set_xlabel("Personagem")
ax[0].set_ylabel("Grau")
ax[0].set_title("Gráfico de Grau por Personagem")
# Out:
# Text(0.5,1,'Gráfico de Grau por Personagem')

# %%
degree=pd.read_csv(directory+'/Degree.csv',dtype=str)
degree=degree.set_index("ID")
degree.fillna('',inplace=True)
degree = degree["Degree"]
for i in degree.index:
    degree[i] = int(degree[i])
degree = degree.sort_values(ascending=False)
fig, ax = plt.subplots(1,2,figsize=(16,8))
ax[0].plot(degree.values,"o")
ax[0].set_xlabel("Personagens")
ax[0].set_ylabel("Grau")
ax[0].set_title("Gráfico de Grau por Personagem")
ax[1].plot(np.log(list(degree.values)),"o")
ax[1].set_xlabel("Personagens")
ax[1].set_ylabel("log(Grau)")
ax[1].set_title("Gráfico de log(Grau) por Personagem")
plt.plot()
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-c9fa748bd4b8> in <module>()
# ----> 1 degree.groupby("Degree")
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...
